# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy


Nx = 20
Ny = 20

psi = np.zeros(N)      #The 1D grid for calculation

Tx = np.zeros((Nx-2,Ny-2))
for i in range(Nx-2):
    for j in range(Ny-2):
        if i==j:
            Tx[i,j]= -2
        elif np.abs(i-j)==1:
            Tx[i,j]=1
        else:
            Tx[i,j]=0

Ty = np.zeros((Nx-2,Ny-2))
for i in range(Nx-2):
    for j in range(Ny-2):
        if i==j:
            Ty[i,j]= -2
        elif np.abs(i-j)==1:
            Ty[i,j]=1
        else:
            Ty[i,j]=0

print(scipy.sparse.kronsum(Tx,Ty))

#scipy.sparse.kronsum
# Out:
#   (0, 0)	-4.0
#   (0, 1)	1.0
#   (0, 18)	1.0
#   (1, 0)	1.0
#   (1, 1)	-4.0
#   (1, 2)	1.0
#   (1, 19)	1.0
#   (2, 1)	1.0
#   (2, 2)	-4.0
#   (2, 3)	1.0
#   (2, 20)	1.0
#   (3, 2)	1.0
#   (3, 3)	-4.0
#   (3, 4)	1.0
#   (3, 21)	1.0
#   (4, 3)	1.0
#   (4, 4)	-4.0
#   (4, 5)	1.0
#   (4, 22)	1.0
#   (5, 4)	1.0
#   (5, 5)	-4.0
#   (5, 6)	1.0
#   (5, 23)	1.0
#   (6, 5)	1.0
#   (6, 6)	-4.0
#   :	:
#   (317, 317)	-4.0
#   (317, 318)	1.0
#   (318, 300)	1.0
#   (318, 317)	1.0
#   (318, 318)	-4.0
#   (318, 319)	1.0
#   (319, 301)	1.0
#   (319, 318)	1.0
#   (319, 319)	-4.0
#   (319, 320)	1.0
#   (320, 302)	1.0
#   (320, 319)	1.0
#   (320, 320)	-4.0
#   (320, 321)	1.0
#   (321, 303)	1.0
#   (321, 320)	1.0
#   (321, 321)	-4.0
#   (321, 322)	1.0
#   (322, 304)	1.0
#   (322, 321)	1.0
#   (322, 322)	-4.0
#   (322, 323)	1.0
#   (323, 305)	1.0
#   (323, 322)	1.0
#   (323, 323)	-4.0
